# %% [markdown]
# # Need to figure this out!!!

# %%
import pandas as pd

# %%
testData = pd.read_excel('Test_data/testData.xlsx')

# %%
testData
# Out:
#          fl_date mkt_unique_carrier op_unique_carrier origin  \
# 0     2018-01-28                 WN                WN    SNA
# 1     2018-01-08                 AA                YV    CHA
# 2     2018-01-20                 WN                WN    DEN
# 3     2018-01-14                 WN                WN    JAX
# 4     2018-01-04                 WN                WN    BWI
# ...          ...                ...               ...    ...
# 9995  2018-01-12                 DL                DL    DCA
# 9996  2018-01-29                 DL                DL    ATL
# 9997  2018-01-29                 WN                WN    SJC
# 9998  2018-01-08                 DL                OO    FCA
# 9999  2018-01-09                 AA                AA    CLT
#
#       origin_city_name dest         dest_city_name  crs_dep_time  dep_time  \
# 0        Santa Ana, CA  SJC           San Jose, CA          1615      1614
# 1      Chattanooga, TN  DFW  Dallas/Fort Worth, TX          1635      1632
# ...

# %%
testData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   fl_date             10000 non-null  object
#  1   mkt_unique_carrier  10000 non-null  object
#  2   op_unique_carrier   10000 non-null  object
#  3   origin              10000 non-null  object
#  4   origin_city_name    10000 non-null  object
#  5   dest                10000 non-null  object
#  6   dest_city_name      10000 non-null  object
#  7   crs_dep_time        10000 non-null  int64
#  8   dep_time            10000 non-null  int64
#  9   crs_arr_time        10000 non-null  int64
#  10  arr_time            10000 non-null  int64
#  11  taxi_out            10000 non-null  int64
#  12  taxi_in             10000 non-null  int64
#  13  distance            10000 non-null  int64
#  14  arr_delay           10000 non-null  int64
# dtypes: int64(8), object(7)
# ...

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="Flight Predictor")
location = geolocator.geocode("Santa Ana, CA")
print(location.address)
print((location.latitude, location.longitude))
# Out:
# Santa Ana, Orange County, California, United States
# (33.7494951, -117.8732213)

# %%
geolocator.geocode(testData['origin_city_name'][56]).latitude
# Out:
# 42.3602534

# %%
lat_origin = testData['origin_city_name'].to_list()
long_origin = testData['origin_city_name'].to_list()
range(len(lat_origin))
# Out:
# range(0, 10000)

# %%
#latitude_origin = []
#for i in range(len(lat_origin)):
#    try:
#        latitude_origin.append(geolocator.geocode(lat_origin[i]).latitude)
#    except AttributeError:
#        print("'NoneType' object has no attribute 'latitude'")
